# %%
import pandas as pd

df1 = pd.read_csv('D:\FYP\svm\pandas\mean.csv')
df2 = pd.read_csv('D:\FYP\svm\pandas\std.csv')
combined_df = pd.concat([df1, df2], axis=1)
print(combined_df)
# Out:
#     Unnamed: 0       0       1       2       3       4       5       6  \
# 0            0 -0.0953 -0.1041 -0.0730 -0.0303 -0.0983 -0.1160 -0.1421
# 1            1 -0.1006  0.0700  0.0984  0.0686  0.0876 -0.0206  0.0448
# 2            2  0.1792  0.0237  0.0985  0.0811  0.0678  0.0598  0.0439
# 3            0  0.1381 -0.0962  0.0605  0.0171 -0.0037  0.0055  0.0569
# 4            1  0.3517  0.2737  0.1096  0.0020  0.1537  0.1000  0.1128
# ..         ...     ...     ...     ...     ...     ...     ...     ...
# 73           1 -0.0074 -0.3526 -0.2195 -0.1466 -0.3075 -0.1806 -0.3215
# 74           2  0.2170  0.0579 -0.1588 -0.1262  0.0373  0.2303 -0.1413
# 75           0 -0.3078 -0.2126 -0.1177 -0.0154 -0.2963 -0.0134 -0.0145
# 76           1  0.0861 -0.0152  0.0352  0.0835 -0.0106  0.0252  0.1191
# 77           2  0.3215  0.1877  0.0285 -0.1094  0.2010 -0.0255 -0.0318
#
#          7       8  Unnamed: 0       0       1       2       3       4  \
# ...
