# %%
import pandas as pd

df1 = pd.read_csv('D:\FYP\\algo\code\preprocessed_dataset\processed_mean.csv')
df2 = pd.read_csv('D:\FYP\\algo\code\preprocessed_dataset\processed_std.csv')
df3 = pd.read_csv('D:\FYP\\algo\code\preprocessed_dataset\processed_min.csv')
df4 = pd.read_csv('D:\FYP\\algo\code\preprocessed_dataset\processed_max.csv')
df5 = pd.read_csv('D:\FYP\\algo\code\preprocessed_dataset\processed_slope.csv')
df6 = pd.read_csv('D:\FYP\\algo\code\preprocessed_dataset\processed_skew.csv')
df7 = pd.read_csv('D:\FYP\\algo\code\preprocessed_dataset\processed_entropy.csv')
df1=df1.drop(['Unnamed: 0'],axis=1)
df2=df2.drop(['Unnamed: 0'],axis=1)
df3=df3.drop(['Unnamed: 0'],axis=1)
df4=df4.drop(['Unnamed: 0'],axis=1)
df5=df5.drop(['Unnamed: 0'],axis=1)
df6=df6.drop(['Unnamed: 0'],axis=1)
df7=df7.drop(['Unnamed: 0'],axis=1)
combined_df = pd.concat([df1, df2,df3,df4,df5,df6,df7], axis=1)
print(combined_df)
# Out:
#                0             1             2             3             4  \
# 0  -6.190000e-08 -9.150000e-07  4.970000e-08  3.760000e-08 -8.780000e-07
# 1  -3.300000e-06 -1.940000e-07 -4.740000e-07 -4.290000e-07 -1.170000e-06
# 2  -4.420000e-07 -4.450000e-07 -9.260000e-07 -6.770000e-07  1.070000e-07
# 3  -1.990000e-07 -1.170000e-06 -6.690000e-07 -4.030000e-07 -1.120000e-06
# 4  -3.020000e-07  6.480000e-07  3.150000e-07  1.310000e-06  7.180000e-07
# ..           ...           ...           ...           ...           ...
# 73 -1.600000e-06  1.540000e-07 -7.590000e-07 -1.050000e-06 -6.230000e-07
# 74 -6.440000e-08  1.100000e-06  4.180000e-07  1.100000e-07  7.900000e-08
# 75 -5.870000e-07 -9.000000e-07 -1.350000e-06 -1.520000e-06 -1.680000e-06
# 76 -9.930000e-07  2.240000e-06  2.130000e-07  3.570000e-07  9.400000e-07
# 77  1.910000e-06  3.070000e-06  2.080000e-06  1.220000e-06  3.100000e-06
#
#                5             6             7             8         0  ...  \
# ...

# %%
out=[]
for i in range(0,78,3):
    for j in [0,2,3]:
        out.append(j)

df=pd.DataFrame(out)
print(df)
# Out:
#     0
# 0   0
# 1   2
# 2   3
# 3   0
# 4   2
# .. ..
# 73  2
# 74  3
# 75  0
# 76  2
# 77  3
#
# [78 rows x 1 columns]

# %%
#df=df.drop(0,axis=1)
combined_df = pd.concat([combined_df,df], axis=1)
print(combined_df)
# Out:
#                0             1             2             3             4  \
# 0  -6.190000e-08 -9.150000e-07  4.970000e-08  3.760000e-08 -8.780000e-07
# 1  -3.300000e-06 -1.940000e-07 -4.740000e-07 -4.290000e-07 -1.170000e-06
# 2  -4.420000e-07 -4.450000e-07 -9.260000e-07 -6.770000e-07  1.070000e-07
# 3  -1.990000e-07 -1.170000e-06 -6.690000e-07 -4.030000e-07 -1.120000e-06
# 4  -3.020000e-07  6.480000e-07  3.150000e-07  1.310000e-06  7.180000e-07
# ..           ...           ...           ...           ...           ...
# 73 -1.600000e-06  1.540000e-07 -7.590000e-07 -1.050000e-06 -6.230000e-07
# 74 -6.440000e-08  1.100000e-06  4.180000e-07  1.100000e-07  7.900000e-08
# 75 -5.870000e-07 -9.000000e-07 -1.350000e-06 -1.520000e-06 -1.680000e-06
# 76 -9.930000e-07  2.240000e-06  2.130000e-07  3.570000e-07  9.400000e-07
# 77  1.910000e-06  3.070000e-06  2.080000e-06  1.220000e-06  3.100000e-06
#
#                5             6             7             8         0  ...  \
# ...

# %%
combined_df.columns
# Out:
# Index(['0', '1', '2', '3', '4', '5', '6', '7', '8', '0', '1', '2', '3', '4',
#        '5', '6', '7', '8', '0', '1', '2', '3', '4', '5', '6', '7', '8', '0',
#        '1', '2', '3', '4', '5', '6', '7', '8', '0', '1', '2', '3', '4', '5',
#        '6', '7', '8', '0', '1', '2', '3', '4', '5', '6', '7', '8', '0', '1',
#        '2', '3', '4', '5', '6', '7', '8',   0],
#       dtype='object')

# %%
combined_df.to_csv('dataset_54_parameters.csv')
