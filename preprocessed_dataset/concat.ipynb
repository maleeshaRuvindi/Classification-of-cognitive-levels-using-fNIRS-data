# %%
import pandas as pd

df1 = pd.read_csv('D:\FYP\\algo\code\pandas\mean.csv')
df2 = pd.read_csv('D:\FYP\\algo\code\pandas\std.csv')
df3 = pd.read_csv('D:\FYP\\algo\code\pandas\min.csv')
df4 = pd.read_csv('D:\FYP\\algo\code\pandas\max.csv')
df5 = pd.read_csv('D:\FYP\\algo\code\pandas\slope.csv')
df6 = pd.read_csv('D:\FYP\\algo\code\pandas\skew.csv')
df1=df1.drop(['Unnamed: 0'],axis=1)
df2=df2.drop(['Unnamed: 0'],axis=1)
df3=df3.drop(['Unnamed: 0'],axis=1)
df4=df4.drop(['Unnamed: 0'],axis=1)
df5=df5.drop(['Unnamed: 0'],axis=1)
df6=df6.drop(['Unnamed: 0'],axis=1)
combined_df = pd.concat([df1, df2,df3,df4,df5,df6], axis=1)
print(combined_df)
# Out:
#          0       1       2       3       4       5       6       7       8  \
# 0  -0.0953 -0.1041 -0.0730 -0.0303 -0.0983 -0.1160 -0.1421 -0.4881 -0.0329
# 1  -0.1006  0.0700  0.0984  0.0686  0.0876 -0.0206  0.0448  0.0264  0.0254
# 2   0.1792  0.0237  0.0985  0.0811  0.0678  0.0598  0.0439  0.4445  0.0621
# 3   0.1381 -0.0962  0.0605  0.0171 -0.0037  0.0055  0.0569  0.0067 -0.0131
# 4   0.3517  0.2737  0.1096  0.0020  0.1537  0.1000  0.1128  0.1291  0.0879
# ..     ...     ...     ...     ...     ...     ...     ...     ...     ...
# 73 -0.0074 -0.3526 -0.2195 -0.1466 -0.3075 -0.1806 -0.3215 -0.1760 -0.1721
# 74  0.2170  0.0579 -0.1588 -0.1262  0.0373  0.2303 -0.1413  0.4023  0.1349
# 75 -0.3078 -0.2126 -0.1177 -0.0154 -0.2963 -0.0134 -0.0145 -0.1236 -0.0163
# 76  0.0861 -0.0152  0.0352  0.0835 -0.0106  0.0252  0.1191 -0.0674  0.0751
# 77  0.3215  0.1877  0.0285 -0.1094  0.2010 -0.0255 -0.0318 -0.0719 -0.0196
#
# ...

# %%
out=[]
for i in range(0,78,3):
    for j in [0,2,3]:
        out.append(j)

df=pd.DataFrame(out)
print(df)
# Out:
#     0
# 0   0
# 1   2
# 2   3
# 3   0
# 4   2
# .. ..
# 73  2
# 74  3
# 75  0
# 76  2
# 77  3
#
# [78 rows x 1 columns]

# %%
#df=df.drop(0,axis=1)
combined_df = pd.concat([combined_df,df], axis=1)
print(combined_df)
# Out:
#          0       1       2       3       4       5       6       7       8  \
# 0  -0.0953 -0.1041 -0.0730 -0.0303 -0.0983 -0.1160 -0.1421 -0.4881 -0.0329
# 1  -0.1006  0.0700  0.0984  0.0686  0.0876 -0.0206  0.0448  0.0264  0.0254
# 2   0.1792  0.0237  0.0985  0.0811  0.0678  0.0598  0.0439  0.4445  0.0621
# 3   0.1381 -0.0962  0.0605  0.0171 -0.0037  0.0055  0.0569  0.0067 -0.0131
# 4   0.3517  0.2737  0.1096  0.0020  0.1537  0.1000  0.1128  0.1291  0.0879
# ..     ...     ...     ...     ...     ...     ...     ...     ...     ...
# 73 -0.0074 -0.3526 -0.2195 -0.1466 -0.3075 -0.1806 -0.3215 -0.1760 -0.1721
# 74  0.2170  0.0579 -0.1588 -0.1262  0.0373  0.2303 -0.1413  0.4023  0.1349
# 75 -0.3078 -0.2126 -0.1177 -0.0154 -0.2963 -0.0134 -0.0145 -0.1236 -0.0163
# 76  0.0861 -0.0152  0.0352  0.0835 -0.0106  0.0252  0.1191 -0.0674  0.0751
# 77  0.3215  0.1877  0.0285 -0.1094  0.2010 -0.0255 -0.0318 -0.0719 -0.0196
#
# ...

# %%
combined_df.columns
# Out:
# Index(['0', '1', '2', '3', '4', '5', '6', '7', '8', '0', '1', '2', '3', '4',
#        '5', '6', '7', '8', '0', '1', '2', '3', '4', '5', '6', '7', '8', '0',
#        '1', '2', '3', '4', '5', '6', '7', '8', '0', '1', '2', '3', '4', '5',
#        '6', '7', '8', '0', '1', '2', '3', '4', '5', '6', '7', '8',   0],
#       dtype='object')

# %%
combined_df.to_csv('dataset_54_parameters.csv')
