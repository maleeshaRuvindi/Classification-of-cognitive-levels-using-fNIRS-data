# %%
import pandas as pd

df = pd.read_csv('D:\FYP\\algo\code\preprocessed_dataset\Prossessed Data-Features spreadsheet - std.csv')

# %%
#print(df.head(10))

# %%
#df.info

# %%
#df.index

# %%
#df.columns

# %%
#df.loc[2,'Participant']

# %%
df=df.drop(0)
df=df.drop(['Participant'],axis=1)
print(df)
# Out:
#    Unnamed: 1         1         2         3         4         5         6  \
# 1      0 back  0.006200  0.000820  0.001600  0.001200  0.003600  0.001500
# 2      2 back  0.006700  0.000664  0.001100  0.001600  0.003400  0.000946
# 3      3 back  0.007200  0.000664  0.001100  0.001600  0.003500  0.000994
# 4      0 back  0.001300  0.000845  0.000352  0.000832  0.000715  0.000577
# 5      2 back  0.001600  0.000543  0.000274  0.000896  0.000771  0.000534
# 6      3 back  0.001700  0.000568  0.000273  0.000945  0.000812  0.000543
# 7      0 back  0.000948  0.001000  0.000557  0.000742  0.000591  0.000825
# 8      2 back  0.000856  0.000682  0.000785  0.000828  0.000465  0.000892
# 9      3 back  0.000903  0.000650  0.000813  0.000865  0.000486  0.000949
# 10     0 back  0.000836  0.001400  0.000539  0.000554  0.001000  0.000789
# 11     2 back  0.000647  0.001400  0.000625  0.000639  0.000824  0.000750
# 12     3 back  0.000645  0.001300  0.000660  0.000663  0.000877  0.000803
# ...

# %%
df=df.drop(['Unnamed: 1'],axis=1)

# %%
#print(df)

# %%
#print(df.iloc[:,0])#0th column

# %%
# data=[]


# for i in range(0,27,3):
#     print(df.iloc[i:i+3,0].tolist())
#     data.append(df.iloc[i:i+3,0].tolist())
# newdf=pd.DataFrame(data)
# #print(newdf)
# #print(df.iloc[0,3:6])
# #newdf['3'] = df.iloc[3:6,0]
# #newdf.insert(loc=1, column='new_column', value=df.iloc[3:6,0])

# print(newdf.T)

# %%
data=[]
combined_df=pd.DataFrame(data)
for j in range(0,26):
    data=[]
    for i in range(0,27,3):
        data.append(df.iloc[i:i+3,j].tolist())
    newdf=pd.DataFrame(data)
    combined_df = pd.concat([combined_df, newdf.T])
    #print(newdf.T)
print(combined_df)
combined_df.to_csv('processed_std.csv')  # Replace 'your_file.csv' with your desired filename
# Out:
#            0         1         2         3         4         5         6  \
# 0   0.006200  0.001300  0.000948  0.000836  0.000795  0.001300  0.000671
# 1   0.006700  0.001600  0.000856  0.000647  0.000872  0.001200  0.000783
# 2   0.007200  0.001700  0.000903  0.000645  0.000920  0.001200  0.000826
# 0   0.000820  0.000845  0.001000  0.001400  0.000953  0.001100  0.000728
# 1   0.000664  0.000543  0.000682  0.001400  0.000633  0.000779  0.000564
# ..       ...       ...       ...       ...       ...       ...       ...
# 1   0.001300  0.000503  0.000436  0.000594  0.000514  0.000473  0.000401
# 2   0.001400  0.000508  0.000456  0.000626  0.000528  0.000480  0.000428
# 0   0.001000  0.000942  0.000656  0.000651  0.000830  0.001300  0.000755
# 1   0.001200  0.000984  0.000589  0.000606  0.000860  0.001300  0.000669
# 2   0.001300  0.000992  0.000590  0.000621  0.000863  0.001400  0.000681
#
#            7         8
# 0   0.001900  0.000987
# 1   0.002200  0.000833
# ...
